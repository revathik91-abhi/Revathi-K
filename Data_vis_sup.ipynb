# %% [markdown]
# <a href="https://colab.research.google.com/github/revathik91-abhi/Revathi-K/blob/main/Data_vis_sup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ✅ Step 1 — Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ✅ Step 2 — Load Dataset

# %%
df = pd.read_csv("/content/supermarket_sales_500_rows (1).csv")

# %% [markdown]
# ✅ Step 3 — Sales by Product Line (Bar Chart)

# %%
sales_product = df.groupby('Product Line')['Total'].sum()
plt.figure()
sales_product.plot(kind='bar')
plt.title("Sales by Product Line")
plt.xlabel("Product Line")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# ✅ Step 4 — Sales by City (Pie Chart)

# %%
sales_city = df.groupby('City')['Total'].sum()
plt.figure()
sales_city.plot(kind='pie', autopct='%1.1f%%')
plt.title("Sales by City")
plt.ylabel("")
plt.show()

# %% [markdown]
# ✅ Step 5 — Monthly Sales (Line Chart)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
monthly_sales = df.groupby('Month')['Total'].sum()
plt.figure()
monthly_sales.plot(kind='line', marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# ✅ Step 6 — Product Line vs Quantity (Bar Chart)

# %%
qty = df.groupby('Product Line')['Quantity'].sum()
plt.figure()
qty.plot(kind='bar')
plt.title("Quantity Sold by Product Line")
plt.xlabel("Product Line")
plt.ylabel("Quantity")
plt.show()

# %% [markdown]
# ✅ Step 7 — Rating Distribution (Histogram)

# %%
plt.figure()
plt.hist(df['Rating'])
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ✅ Step 8 — Total vs Quantity (Scatter Plot)

# %%
plt.figure()
plt.scatter(df['Quantity'], df['Total'])
plt.title("Total vs Quantity")
plt.xlabel("Quantity")
plt.ylabel("Total")
plt.show()
